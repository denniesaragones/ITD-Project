# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seeborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
birdfeather = pd.read_csv('datasets\\penguins.csv')

# %%
birdfeather
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
birdfeather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
birdfeather.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
birdfeather['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
birdfeather['rowid']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 339    340
# 340    341
# 341    342
# 342    343
# 343    344
# Name: rowid, Length: 344, dtype: int64

# %%
birdfeather['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339    55.8
# 340    43.5
# 341    49.6
# 342    50.8
# 343    50.2
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
birdfeather['bill_depth_mm']
# Out:
# 0      18.7
# 1      17.4
# 2      18.0
# 3       NaN
# 4      19.3
#        ...
# 339    19.8
# 340    18.1
# 341    18.2
# 342    19.0
# 343    18.7
# Name: bill_depth_mm, Length: 344, dtype: float64

# %%
birdfeather['flipper_length_mm']
# Out:
# 0      181.0
# 1      186.0
# 2      195.0
# 3        NaN
# 4      193.0
#        ...
# 339    207.0
# 340    202.0
# 341    193.0
# 342    210.0
# 343    198.0
# Name: flipper_length_mm, Length: 344, dtype: float64

# %%
birdfeather['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
birdfeather['species'].values
# Out:
# array(['Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
# ...

# %%
birdfeather
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
birdfeather['weight'] = birdfeather['body_mass_g'] / 1000

# %%
birdfeather['weight'] = np.round(birdfeather['body_mass_g'] / 1000 , 2)

# %%
birdfeather
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007    3.75
# 1                186.0       3800.0  female  2007    3.80
# ...

# %%
birdfeather.isnull()
# Out:
#      rowid  species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    False    False   False           False          False              False
# 1    False    False   False           False          False              False
# 2    False    False   False           False          False              False
# 3    False    False   False            True           True               True
# 4    False    False   False           False          False              False
# ..     ...      ...     ...             ...            ...                ...
# 339  False    False   False           False          False              False
# 340  False    False   False           False          False              False
# 341  False    False   False           False          False              False
# 342  False    False   False           False          False              False
# 343  False    False   False           False          False              False
#
# ...

# %%
birdfeather.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birdfeather['body_mass_g'].sum()
# Out:
# np.float64(1437000.0)

# %%
birdfeather.count()
# Out:
# rowid                344
# species              344
# island               344
# bill_length_mm       342
# bill_depth_mm        342
# flipper_length_mm    342
# body_mass_g          342
# sex                  333
# year                 344
# weight               342
# dtype: int64

# %%
birdfeather['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
birdfeather['bill_length_mm'].median()
# Out:
# np.float64(44.45)

# %%
birdfeather['bill_length_mm'].mode()
# Out:
# 0    41.1
# Name: bill_length_mm, dtype: float64

# %%
birdfeather['bill_length_mm'] = birdfeather['bill_length_mm'].mean()

# %%
birdfeather['bill_length_mm'] = birdfeather['bill_length_mm'].fillna(birdfeather['bill_length_mm'].mean())

# %%
birdfeather['bill_depth_mm'] = birdfeather['bill_depth_mm'].mean()

# %%
birdfeather['bill_depth_mm'] = birdfeather['bill_depth_mm'].fillna(birdfeather['bill_depth_mm'].mean())

# %%
birdfeather['flipper_length_mm'] = birdfeather['flipper_length_mm'].mean()

# %%
birdfeather['flipper_length_mm'] = birdfeather['flipper_length_mm'].fillna(birdfeather['flipper_length_mm'].mean())

# %%
birdfeather['body_mass_g'] = birdfeather['body_mass_g'].mean()

# %%
birdfeather['body_mass_g'] = birdfeather['body_mass_g'].fillna(birdfeather['body_mass_g'].mean())

# %%
birdfeather['sex'] = birdfeather['sex'].mode()

# %%
birdfeather['sex'] = birdfeather['sex'].fillna(birdfeather['sex'].mode())

# %%
birdfeather['year'] = birdfeather['year'].mode()

# %%
birdfeather['year'] = birdfeather['year'].fillna(birdfeather['year'].mode())

# %%
birdfeather['weight'] = birdfeather['weight'].mode()

# %%
birdfeather['weight'] = birdfeather['weight'].fillna(birdfeather['weight'].mode())

# %%
birdfeather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
#  9   weight             342 non-null    float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 27.0+ KB

# %%
birdfeather['year'] = birdfeather['year'].astype('category')

# %%
birdfeather['species'] = birdfeather['species'].astype('category')

# %%
birdfeather['rowid'] = birdfeather['rowid'].astype('category')

# %%
birdfeather['island'] = birdfeather['island'].astype('category')

# %%
birdfeather['sex'] = birdfeather['sex'].astype('category')

# %%
birdfeather.tail(200)
# Out:
#     rowid    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 144   145     Adelie  Dream        43.92193       17.15117         200.915205
# 145   146     Adelie  Dream        43.92193       17.15117         200.915205
# 146   147     Adelie  Dream        43.92193       17.15117         200.915205
# 147   148     Adelie  Dream        43.92193       17.15117         200.915205
# 148   149     Adelie  Dream        43.92193       17.15117         200.915205
# ..    ...        ...    ...             ...            ...                ...
# 339   340  Chinstrap  Dream        43.92193       17.15117         200.915205
# 340   341  Chinstrap  Dream        43.92193       17.15117         200.915205
# 341   342  Chinstrap  Dream        43.92193       17.15117         200.915205
# 342   343  Chinstrap  Dream        43.92193       17.15117         200.915205
# 343   344  Chinstrap  Dream        43.92193       17.15117         200.915205
#
# ...

# %%
birdfeather.head(200)
# Out:
#     rowid species     island  bill_length_mm  bill_depth_mm  \
# 0       1  Adelie  Torgersen        43.92193       17.15117
# 1       2  Adelie  Torgersen        43.92193       17.15117
# 2       3  Adelie  Torgersen        43.92193       17.15117
# 3       4  Adelie  Torgersen        43.92193       17.15117
# 4       5  Adelie  Torgersen        43.92193       17.15117
# ..    ...     ...        ...             ...            ...
# 195   196  Gentoo     Biscoe        43.92193       17.15117
# 196   197  Gentoo     Biscoe        43.92193       17.15117
# 197   198  Gentoo     Biscoe        43.92193       17.15117
# 198   199  Gentoo     Biscoe        43.92193       17.15117
# 199   200  Gentoo     Biscoe        43.92193       17.15117
#
#      flipper_length_mm  body_mass_g   sex  year  weight
# 0           200.915205  4201.754386  male  2009    3.75
# 1           200.915205  4201.754386   NaN   NaN    3.80
# 2           200.915205  4201.754386   NaN   NaN    3.25
# ...

# %%
birdfeather['species'] == "chinstrap"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birdfeather[birdfeather['species'] == "Chinstrap"].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                   0
# year                  0
# weight               68
# dtype: int64
